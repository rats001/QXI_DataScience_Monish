# %%
import seaborn as sns
from numpy import random
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.distplot([1,2,3,4,5])

# %%
sns.distplot([1,2,3,4,5],hist=False)

# %%
sns.distplot(random.normal(size=50),hist=False)

# %%
# Binomial 
# Eg : Coin toss

# %%
sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True) #,kde=False

# %%
from sklearn import datasets

# %%
model= datasets.load_diabetes()

# %%
sns.distplot(model.data)

# %%
sns.distplot(model.data,bins=20,color='g')

# %%
plt.style.use("dark_background")

# %%
sns.distplot(model.data,bins=20,color='g')

# %%
# Plottting the scatter plot

# %%
# plt.scatter(model.data[:-10],model.target[10:])

# %%
x1 = model['data'][:,np.newaxis,2]
x1;
x = x1[:100]
x
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
y = model['target'][-100:]
y.shape
# Out:
# (100,)

# %%
plt.style.use("dark_background")
plt.scatter(x,y)
