# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
Year = [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010]
Unemployment_Rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]

# %%
plt.plot(Year,Unemployment_Rate)
plt.title('Unemployment Rate Vs Year')
plt.xlabel('Year')
plt.ylabel('No of Unemployment ')
plt.grid(True)
plt.show()

# %%
## Adding the color to graph

# %%
plt.plot(Year,Unemployment_Rate,color='red',marker='o')
plt.title('Unemployment Rate Vs Year')
plt.xlabel('Year')
plt.ylabel('No of Unemployment ')
plt.grid(True)
plt.show()

# %%
data ={'Year' : [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010],
       'Unemployment_Rate' : [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Year  Unemployment_Rate
# 0  1920                9.8
# 1  1930               12.0
# 2  1940                8.0
# 3  1950                7.2
# 4  1960                6.9
# 5  1970                7.0
# 6  1980                6.5
# 7  1990                6.2
# 8  2000                5.5
# 9  2010                6.3

# %%
plt.plot(df['Year'],df['Unemployment_Rate'],color='Green',marker='o')
plt.title('Unemployment Chart')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt.grid()
plt.show()

# %% [markdown]
# ## Bar chart

# %%
l1 = ['eat','sleep','drink']

# %%
print(enumerate(l1))

# %%
print(list(enumerate(l1)))
# Out:
# [(0, 'eat'), (1, 'sleep'), (2, 'drink')]

# %%
x = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 22, 24, 8]

# %%
# x_pos = [x for x,_ in enumerate(x)]
# print(x_pos)

# %%
# %matplotlib inline
# x_pos = [x for x , _ in enumerate(x)]
plt.style.use('ggplot')
plt.bar(x,energy,color='green')
plt.xlabel('Engery Source')
plt.ylabel('Engery Output')
# plt.grid(True)
plt.show()

# %%
N = 5
men_means = (20, 35, 30, 35, 27)
women_means = (25, 32, 34, 20, 25)

ind = np.arange(N) 
width = 0.38  
plt.bar(ind, men_means, width, label='Men')
plt.bar(ind + width, women_means, width,label='Women')

plt.ylabel('Scores')
plt.title('Scores by group and gender')

plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Bar Demo

# %%
countries = ['USA', 'GB', 'China', 'Russia', 'Germany']
bronzes = np.array([38, 17, 26, 19, 15])
silvers = np.array([37, 23, 18, 18, 10])
golds = np.array([46, 27, 26, 19, 17])
ind = [x for x, _ in enumerate(countries)]
ind
# Out:
# [0, 1, 2, 3, 4]

# %%
plt.bar(ind, golds, width=0.8, label='golds', color='gold', bottom=silvers+bronzes)
plt.bar(ind, silvers, width=0.8, label='silvers', color='silver', bottom=bronzes)
plt.bar(ind, bronzes, width=0.8, label='bronzes', color='#CD853F')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(ind, golds, width=0.6, label='golds', color='gold', bottom=silvers+bronzes)
plt.bar(ind, silvers, width=0.6, label='silvers', color='silver', bottom=bronzes)
plt.bar(ind, bronzes, width=0.6, label='bronzes', color='#CD853F')
plt.xticks(ind, countries)
plt.ylabel("Medals")
plt.xlabel("Countries")
plt.legend(loc="upper right")
plt.title("2012 Olympics Top Scorers")
plt.show()

# %%
arr1 = np.array([20,40,60,80])

# %%
arr1
# Out:
# array([20, 40, 60, 80])

# %%
data = [i  for i,_ in enumerate(arr1)]

# %%
data
# Out:
# [0, 1, 2, 3]

# %% [markdown]
# ## Hist Demo

# %%
from sklearn import datasets

# %%
model = datasets.load_iris()

# %%
model.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
print(model.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
# print(model.DESCR)

# %%
df = pd.DataFrame(model['data'])
# model.hist(bins=50,figsize=(20,5))

# %%
df.hist(bins=20,figsize=(10,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017F730F2508>,
# ...
#       dtype=object)

# %% [markdown]
# ## Scatter Demo

# %%
# x1 = model.data[:,np.newaxis,2]
# x1 = model.data
# y = model.target
# y.shape
x = np.random.normal(5.0, 1.0, 1000)
y = np.random.normal(10.0, 2.0, 1000)

# %%
plt.scatter(x,y)

# %%
arr =np.arange(0,20,1)

# %%
arr[-5:]
# Out:
# array([15, 16, 17, 18, 19])

# %%
arr[:-5]
# Out:
# array([0, 1, 2, 3, 4])
